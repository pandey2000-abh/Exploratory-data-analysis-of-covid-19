# %%
import pandas as pd

# %%
data=pd.read_csv("C:\\Users\\Abhishek kumar\\Downloads\\Covid_19_data.csv")

# %%
data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
data.tail()
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263

# %%
data.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\Abhishek kumar\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# 1. Show the number of Confirmed,Deaths and Recovered cases in each Region

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.groupby('Region').sum().head(20)
# Out:
#                      Confirmed  Deaths  Recovered
# Region
# Afghanistan               1939      60        252
# Albania                    766      30        455
# Algeria                   3848     444       1702
# Andorra                    743      42        423
# Angola                      27       2          7
# Antigua and Barbuda         24       3         11
# Argentina                 4285     214       1192
# Armenia                   1932      30        900
# Australia                 6752      91       5715
# Austria                  15402     580      12779
# Azerbaijan                1766      23       1267
# Bahamas                     80      11         23
# Bahrain                   2921       8       1455
# Bangladesh                7103     163        150
# Barbados                    80       7         39
# Belarus                  13181      84       2072
# Belgium                  47859    7501      11283
# Belize                      18       2          9
# ...

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending=False)
# Out:
# Region
# US                       1039909
# Spain                     236899
# Italy                     203591
# France                    166543
# UK                        166441
#                           ...
# Sao Tome and Principe          8
# Papua New Guinea               8
# Bhutan                         7
# Western Sahara                 6
# Yemen                          6
# Name: Confirmed, Length: 187, dtype: int64

# %%
data.groupby('Region')['Confirmed','Recovered','Deaths'].sum()  # ans
# Out:
# C:\Users\ABHISH~1\AppData\Local\Temp/ipykernel_13428/823448317.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('Region')['Confirmed','Recovered','Deaths'].sum()  # ans
#                     Confirmed  Recovered  Deaths
# Region
# Afghanistan              1939        252      60
# Albania                   766        455      30
# Algeria                  3848       1702     444
# Andorra                   743        423      42
# Angola                     27          7       2
# ...                       ...        ...     ...
# West Bank and Gaza        344         71       2
# Western Sahara              6          5       0
# Yemen                       6          1       0
# Zambia                     97         54       3
# Zimbabwe                   32          5       4
#
# [187 rows x 3 columns]

# %% [markdown]
# 2. Removed all the records where Confirmed Cases is Less Than 10.

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data[data.Confirmed < 10]
# Out:
#           Date                             State                 Region  \
# 18   4/29/2020                               NaN                 Bhutan
# 98   4/29/2020                               NaN             MS Zaandam
# 105  4/29/2020                               NaN             Mauritania
# 126  4/29/2020                               NaN       Papua New Guinea
# 140  4/29/2020                               NaN  Sao Tome and Principe
# 177  4/29/2020                               NaN         Western Sahara
# 178  4/29/2020                               NaN                  Yemen
# 184  4/29/2020                          Anguilla                     UK
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba            Netherlands
# 194  4/29/2020            British Virgin Islands                     UK
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# 272  4/29/2020             Northwest Territories                 Canada
# ...

# %%
data=data[~(data.Confirmed < 10)]  # ans

# %%
data.head(20)
# Out:
#          Date State                  Region  Confirmed  Deaths  Recovered
# 0   4/29/2020   NaN             Afghanistan       1939      60        252
# 1   4/29/2020   NaN                 Albania        766      30        455
# 2   4/29/2020   NaN                 Algeria       3848     444       1702
# 3   4/29/2020   NaN                 Andorra        743      42        423
# 4   4/29/2020   NaN                  Angola         27       2          7
# 5   4/29/2020   NaN     Antigua and Barbuda         24       3         11
# 6   4/29/2020   NaN               Argentina       4285     214       1192
# 7   4/29/2020   NaN                 Armenia       1932      30        900
# 8   4/29/2020   NaN                 Austria      15402     580      12779
# 9   4/29/2020   NaN              Azerbaijan       1766      23       1267
# 10  4/29/2020   NaN                 Bahamas         80      11         23
# 11  4/29/2020   NaN                 Bahrain       2921       8       1455
# ...

# %% [markdown]
# 3. In which Region,maximum number of Confirmed cases were recorded ?

# %%
data.groupby('Region').Confirmed.sum().sort_values(ascending = False)
# Out:
# Region
# US            1039909
# Spain          236899
# Italy          203591
# France         166536
# UK             166432
#                ...
# Seychelles         11
# Burundi            11
# Suriname           10
# Gambia             10
# Holy See           10
# Name: Confirmed, Length: 180, dtype: int64

# %% [markdown]
# 4.in which Region,minimum number of Deaths cases were recorded ?

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.groupby('Region').Deaths.sum().sort_values(ascending = True).head(50)
# Out:
# Region
# Cambodia                            0
# Seychelles                          0
# Saint Lucia                         0
# Central African Republic            0
# Saint Kitts and Nevis               0
# South Sudan                         0
# Rwanda                              0
# Grenada                             0
# Macau                               0
# Madagascar                          0
# Nepal                               0
# Namibia                             0
# Saint Vincent and the Grenadines    0
# Mozambique                          0
# Holy See                            0
# Timor-Leste                         0
# Mongolia                            0
# Uganda                              0
# Laos                                0
# Eritrea                             0
# Vietnam                             0
# Fiji                                0
# Dominica                            0
# Gambia                              1
# ...

# %% [markdown]
# 5. How many Confirmed,Deaths & Recovered cases were reported from india till 29 April 2020 ?

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data[data.Region =='India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %%
data[data.Region =='Argentina']
# Out:
#         Date State     Region  Confirmed  Deaths  Recovered
# 6  4/29/2020   NaN  Argentina       4285     214       1192

# %% [markdown]
# 6-A) Sort the entire data wrt No.of Confirmed cases in ascending order

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
data.sort_values(by=['Confirmed'],ascending=True).head(50)
# Out:
#           Date                         State  \
# 156  4/29/2020                           NaN
# 70   4/29/2020                           NaN
# 59   4/29/2020                           NaN
# 318  4/29/2020                         Yukon
# 217  4/29/2020                     Greenland
# 256  4/29/2020                    Montserrat
# 144  4/29/2020                           NaN
# 27   4/29/2020                           NaN
# 306  4/29/2020      Turks and Caicos Islands
# 118  4/29/2020                           NaN
# 215  4/29/2020                Grand Princess
# 206  4/29/2020   Falkland Islands (Malvinas)
# 270  4/29/2020      Northern Mariana Islands
# 136  4/29/2020                           NaN
# 138  4/29/2020                           NaN
# 45   4/29/2020                           NaN
# 201  4/29/2020                       Curacao
# 114  4/29/2020                           NaN
# 137  4/29/2020                           NaN
# 260  4/29/2020                 New Caledonia
# ...

# %% [markdown]
# 6-B) Sort the entire data wrt No. of Recovered cases in descending order

# %%
data.sort_values(by=['Recovered'],ascending=True).head(50)
# Out:
#           Date                         State       Region  Confirmed  Deaths  \
# 199  4/29/2020                      Colorado           US      14758     766
# 276  4/29/2020                       Ontario       Canada      16978    1153
# 116  4/29/2020                           NaN  Netherlands      38802    4711
# 246  4/29/2020                      Manitoba       Canada        275       6
# 277  4/29/2020                        Oregon           US       2446     101
# 278  4/29/2020                  Pennsylvania           US      46327    2373
# 245  4/29/2020                         Maine           US       1056      52
# 243  4/29/2020                     Louisiana           US      27660    1845
# 275  4/29/2020                      Oklahoma           US       3473     214
# 241  4/29/2020                      Kentucky           US       4537     234
# 235  4/29/2020                          Iowa           US       6843     148
# ...
